# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Lovenchia Cheren Melinda Warouw]
# - **Email:** [lovenchiawarouw@gmail.com]
# - **ID Dicoding:** [lovenchia]

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %% [markdown]
# ## Memanggil Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data
# **Mengumpulkan semua data yang dibutuhkan**

# %%
day_df = pd.read_csv("D:\submission\data\day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("D:\submission\data\hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data
# **Menilai kualitas dari seluruh data**

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ",day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data
# **Pada tahap ini kita akan membersihkan berbagai masalah yang teridentifikasi dalam proses assessing data.**

# %% [markdown]
# **Cleaning data merupakan pembersihan data sebelum melanjutkan ke analisis data. Agar datanya bersih dan terstuktur dengan aman sehingga dapat digunakan dalam pemodelan atau visualisasi data.**

# %%
day_df.rename(columns={'instant':'Instant',
                       'dteday':'Datetimes',
                       'season':'Season',
                       'yr':'Year',
                       'mnth':'Month',
                       'holiday':'Holiday',
                       'weekday':'Weekday',
                       'workingday':'Workingday',
                       'weathersit':'WeatherSituation',
                       'temp':'Temperature',
                       'atemp':'ApparentTemperature',
                       'hum':'Humidity',
                       'windspeed':'WindSpeed',
                       'casual':'Casual',
                       'registered':'Registered',
                       'cnt':'Count'},inplace=True)

# %%
hour_df.rename(columns={'instant':'Instant',
                       'dteday':'Datetimes',
                       'season':'Season',
                       'yr':'Year',
                       'mnth':'Month',
                       'hr':'Day',
                       'holiday':'Holiday',
                       'weekday':'Weekday',
                       'workingday':'Workingday',
                       'weathersit':'WeatherSituation',
                       'temp':'Temperature',
                       'atemp':'ApparentTemperature',
                       'hum':'Humidity',
                       'windspeed':'WindSpeed',
                       'casual':'Casual',
                       'registered':'Registered',
                       'cnt':'Count'},inplace=True)

# %%
day_df.head()
# Out:
#    Instant   Datetimes  Season  Year  Month  Holiday  Weekday  Workingday  \
# 0        1  2011-01-01       1     0      1        0        6           0
# 1        2  2011-01-02       1     0      1        0        0           0
# 2        3  2011-01-03       1     0      1        0        1           1
# 3        4  2011-01-04       1     0      1        0        2           1
# 4        5  2011-01-05       1     0      1        0        3           1
#
#    WeatherSituation  Temperature  ApparentTemperature  Humidity  WindSpeed  \
# 0                 2     0.344167             0.363625  0.805833   0.160446
# 1                 2     0.363478             0.353739  0.696087   0.248539
# 2                 1     0.196364             0.189405  0.437273   0.248309
# 3                 1     0.200000             0.212122  0.590435   0.160296
# 4                 1     0.226957             0.229270  0.436957   0.186900
#
#    Casual  Registered  Count
# 0     331         654    985
# ...

# %%
hour_df.head()
# Out:
#    Instant   Datetimes  Season  Year  Month  Day  Holiday  Weekday  \
# 0        1  2011-01-01       1     0      1    0        0        6
# 1        2  2011-01-01       1     0      1    1        0        6
# 2        3  2011-01-01       1     0      1    2        0        6
# 3        4  2011-01-01       1     0      1    3        0        6
# 4        5  2011-01-01       1     0      1    4        0        6
#
#    Workingday  WeatherSituation  Temperature  ApparentTemperature  Humidity  \
# 0           0                 1         0.24               0.2879      0.81
# 1           0                 1         0.22               0.2727      0.80
# 2           0                 1         0.22               0.2727      0.80
# 3           0                 1         0.24               0.2879      0.75
# 4           0                 1         0.24               0.2879      0.75
#
#    WindSpeed  Casual  Registered  Count
# 0        0.0       3          13     16
# ...

# %% [markdown]
# **Karena tidak titemukan masalah pada data. maka kita akan melakukan perubahan ke kolom 'Datetimes' menjadi tipe data datetime. Dan membersihkan data dengan menghapus baris yang memiliki nilai duplikat**

# %%
day_df['Datetimes'] = pd.to_datetime(day_df['Datetimes'], errors='coerce')

day_df_cleaned = day_df.drop_duplicates(subset='Datetimes')

print(day_df_cleaned)
# Out:
#      Instant  Datetimes  Season  Year  Month  Holiday  Weekday  Workingday  \
# 0          1 2011-01-01       1     0      1        0        6           0
# 1          2 2011-01-02       1     0      1        0        0           0
# 2          3 2011-01-03       1     0      1        0        1           1
# 3          4 2011-01-04       1     0      1        0        2           1
# 4          5 2011-01-05       1     0      1        0        3           1
# ..       ...        ...     ...   ...    ...      ...      ...         ...
# 726      727 2012-12-27       1     1     12        0        4           1
# 727      728 2012-12-28       1     1     12        0        5           1
# 728      729 2012-12-29       1     1     12        0        6           0
# 729      730 2012-12-30       1     1     12        0        0           0
# 730      731 2012-12-31       1     1     12        0        1           1
#
# ...

# %%
hour_df['Datetimes'] = pd.to_datetime(hour_df['Datetimes'], errors='coerce')

hour_df_cleaned = hour_df.drop_duplicates(subset='Datetimes')
print(hour_df_cleaned)
# Out:
#        Instant  Datetimes  Season  Year  Month  Day  Holiday  Weekday  \
# 0            1 2011-01-01       1     0      1    0        0        6
# 24          25 2011-01-02       1     0      1    0        0        0
# 47          48 2011-01-03       1     0      1    0        0        1
# 69          70 2011-01-04       1     0      1    0        0        2
# 92          93 2011-01-05       1     0      1    0        0        3
# ...        ...        ...     ...   ...    ...  ...      ...      ...
# 17259    17260 2012-12-27       1     1     12    0        0        4
# 17283    17284 2012-12-28       1     1     12    0        0        5
# 17307    17308 2012-12-29       1     1     12    0        0        6
# 17331    17332 2012-12-30       1     1     12    0        0        0
# 17355    17356 2012-12-31       1     1     12    0        0        1
#
#        Workingday  WeatherSituation  Temperature  ApparentTemperature  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data gunanya untuk menjawab pertanyaan tersebut

# %%
day_df.describe(include="all")
# Out:
#           Instant            Datetimes      Season        Year       Month  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           Holiday     Weekday  Workingday  WeatherSituation  Temperature  \
# count  731.000000  731.000000  731.000000        731.000000   731.000000
# mean     0.028728    2.997264    0.683995          1.395349     0.495385
# ...

# %%
hour_df.describe(include="all")
# Out:
#           Instant                      Datetimes        Season          Year  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#               Month           Day       Holiday       Weekday    Workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
season_pivot = day_df.pivot_table(values='Count', index='Season', aggfunc=['count', 'mean', 'std', 'min', 'max']).reset_index()
season_pivot.columns = ['Season', 'Count_Count', 'Count_Mean', 'Count_Std', 'Count_Min', 'Count_Max']
print("\nTabel Pivot untuk Eksplorasi Perbedaan Tren Penggunaan Sepeda pada Musim Tertentu:")
print(season_pivot)
# Out:
# Tabel Pivot untuk Eksplorasi Perbedaan Tren Penggunaan Sepeda pada Musim Tertentu:
#    Season  Count_Count   Count_Mean    Count_Std  Count_Min  Count_Max
# 0       1          181  2604.132597  1399.942119        431       7836
# 1       2          184  4992.331522  1695.977235        795       8362
# 2       3          188  5644.303191  1459.800381       1115       8714
# 3       4          178  4728.162921  1699.615261         22       8555

# %%
workingday_pivot = day_df.pivot_table(values='Count', index='Workingday', aggfunc=['count', 'mean', 'std', 'min', 'max']).reset_index()
workingday_pivot.columns = ['Workingday', 'Count_Count', 'Count_Mean', 'Count_Std', 'Count_Min', 'Count_Max']
print("Tabel Pivot untuk Eksplorasi Pola Penggunaan Sepeda pada Hari Kerja dan Akhir Pekan:")
print(workingday_pivot)
# Out:
# Tabel Pivot untuk Eksplorasi Pola Penggunaan Sepeda pada Hari Kerja dan Akhir Pekan:
#    Workingday  Count_Count   Count_Mean    Count_Std  Count_Min  Count_Max
# 0           0          231  4330.168831  2052.141245        605       8714
# 1           1          500  4584.820000  1878.415583         22       8362

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# Bagaimana distribusi jumlah peminjaman sepeda pada setiap bulan selama dua tahun?

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Month', y='Count', data=day_df, estimator='sum', ci=None, palette='muted')
plt.title('Distribusi Jumlah Peminjaman Sepeda pada Setiap Bulan')
plt.xlabel('Bulan')
plt.ylabel('Total Jumlah Peminjaman Sepeda')
plt.show()
# Out:
# C:\Users\L e n o v o\AppData\Local\Temp\ipykernel_18212\4059082125.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Month', y='Count', data=day_df, estimator='sum', ci=None, palette='muted')

# %% [markdown]
# ### Pertanyaan 2:
# Bagaimana pengaruh musim terhadap jumlah pengunjung?

# %%
# Display the correlation matrix between numerical features
corr = day_df.corr()

# Visualize and explain the correlation matrix
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, ax=ax)
ax.set_title('Correlation Matrix - Exploratory Analysis')

# Add explanatory analysis
plt.text(-0.5, -0.5, "Exploratory Analysis:\n\n"
           "1. Korelasi tinggi positif antara variabel A dan variabel B.\n"
           "2. Variabel Target memiliki korelasi positif dengan variabel C.\n"
           "3. Korelasi rendah antara variabel X dan variabel Y.\n"
           "4. Perhatikan korelasi dekat dengan 0 pada variabel Z.\n"
           "5. Analisis lebih lanjut diperlukan untuk variabel lainnya.",
           horizontalalignment='left', verticalalignment='center',
           bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

# Show the plot (for Visual Studio Code or any other non-Streamlit environment)
plt.show()

# %%
all_df = pd.concat([day_df, hour_df], ignore_index=True)
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# Terdapat pola dengan puncak aktivitas, terjadi pada bulan-bulan musim semi dan musim panas pada bulan Maret hingga September. Ini menyimpulkan bahwa orang-orang cenderung menggunakan sepeda saat cuaca lebih hangat.
# Dan sebaliknya pada musim dingin jumlah orang peminjam sepeda cenderung menurun.
# - Conclution pertanyaan 2 Dari tampilan data visual di atas kita dapat menyimpulkan bahwa permintaan penyewaan sepeda lebih tinggi pada waktu spontan, hari kerja, dan cuaca yang hangat.
# Promosi untuk meningkatkan penyewaan terdaftar bisa dilakukan. Dan kemudian Bisnis perlu mempertimbangkan faktor cuaca dan hari kerja dalam strategi dan perencanaan.
